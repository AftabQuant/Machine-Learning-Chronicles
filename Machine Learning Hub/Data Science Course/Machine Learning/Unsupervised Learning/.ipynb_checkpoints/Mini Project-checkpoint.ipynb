# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\Ultimate Programming\Data Bases\Machine Learning Datasets\Country-data.csv")
df.head(3)
# Out:
#        country  child_mort  exports  health  imports  income  inflation  \
# 0  Afghanistan        90.2     10.0    7.58     44.9    1610       9.44
# 1      Albania        16.6     28.0    6.55     48.6    9930       4.49
# 2      Algeria        27.3     38.4    4.17     31.4   12900      16.10
#
#    life_expec  total_fer  gdpp
# 0        56.2       5.82   553
# 1        76.3       1.65  4090
# 2        76.5       2.89  4460

# %%
df.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
df.shape
# Out:
# (167, 10)

# %%
sns.pairplot(data=df.drop('country', axis=1))

# %%
x = df.drop('country', axis=1)

# %%
x.head(2)
# Out:
#    child_mort  exports  health  imports  income  inflation  life_expec  \
# 0        90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1        16.6     28.0    6.55     48.6    9930       4.49        76.3
#
#    total_fer  gdpp
# 0       5.82   553
# 1       1.65  4090

# %%
sns.heatmap(x.corr(), annot=True)
plt.show()

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score

# %% [markdown]
# # **K-Means Clustering**

# %%
km = KMeans(n_clusters=2, init='k-means++')
km.fit(x)
# Out:
# KMeans(n_clusters=2)

# %%
x['tar'] = km.fit_predict(x)

# %%
sns.pairplot(x, hue='tar')
plt.show()

# %%
x = x.drop('tar', axis=1)

# %%
wcss = []
clusters = [i for i in range(2,15)]
for i in range(2,15):
    km1 = KMeans(n_clusters=i, init='k-means++')
    km1.fit(x)
    wcss.append(km1.inertia_)

# %%
plt.figure(figsize=(10,5))
plt.plot(clusters, wcss, marker='o')
plt.xticks(clusters)
plt.grid(axis='x')
plt.show()

# %%
ss = []
for i in range(2, 15):
    km2 = KMeans(n_clusters=i, init='k-means++')
    km2.fit(x)
    ss.append(silhouette_score(x, km2.labels_))

# %%
plt.figure(figsize=(10,5))
plt.plot(clusters, ss, marker='o')
plt.xticks(clusters)
plt.grid(axis='x')
plt.show()

# %% [markdown]
# # **Hierarchical Clustering**

# %%
import scipy.cluster.hierarchy as sc
sc.dendrogram(sc.linkage(x, method='single'))
plt.show()

# %%
ac = AgglomerativeClustering(n_clusters=2, linkage='ward')
ac.fit(x)
x['tar'] = ac.fit_predict(x)

# %%
x.head(2)
# Out:
#    child_mort  exports  health  imports  income  inflation  life_expec  \
# 0        90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1        16.6     28.0    6.55     48.6    9930       4.49        76.3
#
#    total_fer  gdpp  tar
# 0       5.82   553    0
# 1       1.65  4090    0

# %%
sns.pairplot(x, hue='tar')
plt.show()

# %%
x = x.drop('tar', axis=1)

# %%
ss = []
for i in range(2, 15):
    ag1 = AgglomerativeClustering(n_clusters=i, linkage='complete')
    ag1.fit(x)
    ss.append(silhouette_score(x, ag1.labels_))

# %%
plt.figure(figsize=(10, 5))
plt.plot(clusters, ss, marker='o')
plt.xticks(clusters)
plt.grid(axis='x')
plt.show()

# %%
x.head(2)
# Out:
#    child_mort  exports  health  imports  income  inflation  life_expec  \
# 0        90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1        16.6     28.0    6.55     48.6    9930       4.49        76.3
#
#    total_fer  gdpp
# 0       5.82   553
# 1       1.65  4090

# %% [markdown]
# # **DBSCAN Clustering**

# %%
db = DBSCAN(eps=0.5)
db.fit(x)
x['tar'] = db.fit_predict(x)

# %%
sns.pairplot(x, hue='tar')
plt.show()
