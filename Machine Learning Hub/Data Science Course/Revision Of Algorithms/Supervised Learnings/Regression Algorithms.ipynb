# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\Ultimate Programming\Data Bases\Machine Learning Datasets\Regression\global_ai_workforce_automation_2015_2025.csv")
df.head(2)
# Out:
#    Year        Country  AI_Investment_BillionUSD  Automation_Rate_Percent  \
# 0  2015  United States                     52.46                    10.75
# 1  2016  United States                     60.64                    11.64
#
#    Employment_Rate_Percent  Average_Salary_USD  Productivity_Index  \
# 0                    65.50            38392.64               65.78
# 1                    65.25            39371.74               67.02
#
#    Reskilling_Investment_MillionUSD  AI_Policy_Index  \
# 0                            709.03             0.64
# 1                            815.38             0.75
#
#    Job_Displacement_Million  Job_Creation_Million  AI_Readiness_Score
# 0                      0.19                  0.14               47.87
# 1                      0.16                  0.85               43.85

# %%
df.shape
# Out:
# (220, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Year                              220 non-null    int64
#  1   Country                           220 non-null    object
#  2   AI_Investment_BillionUSD          220 non-null    float64
#  3   Automation_Rate_Percent           220 non-null    float64
#  4   Employment_Rate_Percent           220 non-null    float64
#  5   Average_Salary_USD                220 non-null    float64
#  6   Productivity_Index                220 non-null    float64
#  7   Reskilling_Investment_MillionUSD  220 non-null    float64
#  8   AI_Policy_Index                   220 non-null    float64
#  9   Job_Displacement_Million          220 non-null    float64
#  10  Job_Creation_Million              220 non-null    float64
# ...

# %%
data = df

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#               Year  AI_Investment_BillionUSD  Automation_Rate_Percent  \
# count   220.000000                220.000000               220.000000
# mean   2020.000000                 82.364409                27.352136
# std       3.169489                 42.522535                 8.860064
# min    2015.000000                  5.400000                10.190000
# 25%    2017.000000                 47.642500                20.337500
# 50%    2020.000000                 81.375000                27.085000
# 75%    2023.000000                114.480000                33.812500
# max    2025.000000                177.290000                48.410000
#
#        Employment_Rate_Percent  Average_Salary_USD  Productivity_Index  \
# count               220.000000          220.000000           220.00000
# mean                 68.818909        62074.483818            60.61450
# std                   5.833969        19472.117474            11.09393
# ...

# %%
sns.histplot(data=df, x='AI_Readiness_Score', kde=True)
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(data.drop('Country', axis=1).corr(), annot=True)
plt.show()

# %%
sns.barplot(data=df, x='Year', y='AI_Investment_BillionUSD')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Job_Displacement_Million', y='Job_Creation_Million', hue='Country')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
data.head(2)
# Out:
#    Year        Country  AI_Investment_BillionUSD  Automation_Rate_Percent  \
# 0  2015  United States                     52.46                    10.75
# 1  2016  United States                     60.64                    11.64
#
#    Employment_Rate_Percent  Average_Salary_USD  Productivity_Index  \
# 0                    65.50            38392.64               65.78
# 1                    65.25            39371.74               67.02
#
#    Reskilling_Investment_MillionUSD  AI_Policy_Index  \
# 0                            709.03             0.64
# 1                            815.38             0.75
#
#    Job_Displacement_Million  Job_Creation_Million  AI_Readiness_Score
# 0                      0.19                  0.14               47.87
# 1                      0.16                  0.85               43.85

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Year                              220 non-null    int64
#  1   Country                           220 non-null    object
#  2   AI_Investment_BillionUSD          220 non-null    float64
#  3   Automation_Rate_Percent           220 non-null    float64
#  4   Employment_Rate_Percent           220 non-null    float64
#  5   Average_Salary_USD                220 non-null    float64
#  6   Productivity_Index                220 non-null    float64
#  7   Reskilling_Investment_MillionUSD  220 non-null    float64
#  8   AI_Policy_Index                   220 non-null    float64
#  9   Job_Displacement_Million          220 non-null    float64
#  10  Job_Creation_Million              220 non-null    float64
# ...

# %%
x = df.drop('AI_Readiness_Score', axis=1)
y = df['AI_Readiness_Score']

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Year                              220 non-null    int64
#  1   Country                           220 non-null    object
#  2   AI_Investment_BillionUSD          220 non-null    float64
#  3   Automation_Rate_Percent           220 non-null    float64
#  4   Employment_Rate_Percent           220 non-null    float64
#  5   Average_Salary_USD                220 non-null    float64
#  6   Productivity_Index                220 non-null    float64
#  7   Reskilling_Investment_MillionUSD  220 non-null    float64
#  8   AI_Policy_Index                   220 non-null    float64
#  9   Job_Displacement_Million          220 non-null    float64
#  10  Job_Creation_Million              220 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer

# %%
ct = ColumnTransformer(
    transformers=[
        ('si', SimpleImputer(), [2, 3, 4, 5, 6, 7, 8, 9, 10]),
        ('ohe', OneHotEncoder(drop='first', sparse_output=False), ['Country']),
        ('ms', MinMaxScaler(), [0, 2, 3, 4, 5, 6, 7, 8, 9, 10])
    ], remainder='passthrough')

# %%
ct.fit(x)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('si', SimpleImputer(),
#                                  [2, 3, 4, 5, 6, 7, 8, 9, 10]),
#                                 ('ohe',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['Country']),
#                                 ('ms', MinMaxScaler(),
#                                  [0, 2, 3, 4, 5, 6, 7, 8, 9, 10])])

# %%
col = ct.get_feature_names_out()
x_en = ct.transform(x)
x_en = pd.DataFrame(x_en, columns=col)

# %%
x['Country'].unique()
# Out:
# array(['United States', 'China', 'India', 'Germany', 'Japan',
#        'South Korea', 'France', 'United Kingdom', 'Canada', 'Australia',
#        'Brazil', 'Russia', 'Netherlands', 'Sweden', 'Turkey', 'Singapore',
#        'Spain', 'Italy', 'South Africa', 'Mexico'], dtype=object)

# %%
x_en.head(4)
# Out:
#    si__AI_Investment_BillionUSD  si__Automation_Rate_Percent  \
# 0                         52.46                        10.75
# 1                         60.64                        11.64
# 2                         66.11                        12.46
# 3                         72.45                        13.35
#
#    si__Employment_Rate_Percent  si__Average_Salary_USD  \
# 0                        65.50                38392.64
# 1                        65.25                39371.74
# 2                        64.93                40772.29
# 3                        64.84                43974.92
#
#    si__Productivity_Index  si__Reskilling_Investment_MillionUSD  \
# 0                   65.78                                709.03
# 1                   67.02                                815.38
# 2                   68.51                                921.74
# 3                   71.09                               1028.09
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x_en, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(positive=False)

lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"Training Accuracy: {round(lr.score(x_train, y_train)*100, 2)}")
print(f"Testing Accuracy: {round(lr.score(x_test, y_test)*100, 2)}")
# Out:
# Training Accuracy: 78.37
# Testing Accuracy: 70.75

# %%
lr.coef_, lr.intercept_
# Out:
# (array([-1.08706630e-02, -2.80729378e-01,  2.82620701e-01, -1.29879670e-04,
#          4.78225349e-01, -8.75440581e-04,  8.31974985e+00,  9.61806785e-01,
#          2.49248476e-02, -7.93013422e+00, -1.14530751e+01, -1.80314089e+01,
#         -1.19636471e+01, -1.62154827e+01, -1.33598397e+01, -2.95971546e+00,
#         -1.30249573e+01, -3.49328842e+00, -1.78742697e+01, -1.47954845e+01,
#         -8.92189675e+00, -9.97026426e+00, -1.78206685e+00, -4.32678303e+00,
#         -1.58933725e+01, -1.53960399e+01, -8.90130875e+00, -1.83500197e+01,
#          6.88243868e+00, -6.32419743e-05, -7.34509099e-03,  1.23793562e-02,
#         -1.43436779e-09,  1.02054065e-02, -3.92519709e-07,  1.01460364e+01,
#          9.71522005e-01,  5.06602593e-03]),
#  np.float64(9.127358506362043))

# %%
print('hello')
# Out:
# hello
