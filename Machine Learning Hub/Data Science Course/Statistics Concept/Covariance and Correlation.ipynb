# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Ultimate Programming\Data Bases\Machine Learning Datasets\Regression\Concrete Compressive Strength.csv")
df.head(2)
# Out:
#    Cement  Blast_Furnance_Slag  Fly_Ash  Water  Superplasticizer  \
# 0   540.0                  0.0      0.0  162.0               2.5
# 1   540.0                  0.0      0.0  162.0               2.5
#
#    Coarse_Aggregate  Fine_Aggregate  Age_Day  Concrete_Strength
# 0            1040.0           676.0       28          79.986111
# 1            1055.0           676.0       28          61.887366

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cement               1030 non-null   float64
#  1   Blast_Furnance_Slag  1030 non-null   float64
#  2   Fly_Ash              1030 non-null   float64
#  3   Water                1030 non-null   float64
#  4   Superplasticizer     1030 non-null   float64
#  5   Coarse_Aggregate     1030 non-null   float64
#  6   Fine_Aggregate       1030 non-null   float64
#  7   Age_Day              1030 non-null   int64
#  8   Concrete_Strength    1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.6 KB

# %%
df.describe()
# Out:
#             Cement  Blast_Furnance_Slag      Fly_Ash        Water  \
# count  1030.000000          1030.000000  1030.000000  1030.000000
# mean    281.165631            73.895485    54.187136   181.566359
# std     104.507142            86.279104    63.996469    21.355567
# min     102.000000             0.000000     0.000000   121.750000
# 25%     192.375000             0.000000     0.000000   164.900000
# 50%     272.900000            22.000000     0.000000   185.000000
# 75%     350.000000           142.950000   118.270000   192.000000
# max     540.000000           359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse_Aggregate  Fine_Aggregate      Age_Day  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.203112        972.918592      773.578883    45.662136
# std            5.973492         77.753818       80.175427    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
plt.figure(figsize=(10,4))
plt.subplot(2,3,1)
sns.kdeplot(data=df, x='Cement',fill=True, color='red')

plt.subplot(2,3,2)
sns.kdeplot(data=df, x='Blast_Furnance_Slag',fill=True, color='red')

plt.subplot(2,3,3)
sns.kdeplot(data=df, x='Fly_Ash',fill=True, color='red')

plt.subplot(2,3,4)
sns.kdeplot(data=df, x='Water',fill=True, color='red')

plt.subplot(2,3,5)
sns.kdeplot(data=df, x='Superplasticizer',fill=True, color='red')

plt.subplot(2,3,6)
sns.kdeplot(data=df, x='Coarse_Aggregate',fill=True, color='red')

plt.tight_layout()
plt.show()

# %%
df.select_dtypes(include=["float64"]).corr()
# Out:
#                        Cement  Blast_Furnance_Slag   Fly_Ash     Water  \
# Cement               1.000000            -0.275193 -0.397475 -0.081544
# Blast_Furnance_Slag -0.275193             1.000000 -0.323569  0.107286
# Fly_Ash             -0.397475            -0.323569  1.000000 -0.257044
# Water               -0.081544             0.107286 -0.257044  1.000000
# Superplasticizer     0.092771             0.043376  0.377340 -0.657464
# Coarse_Aggregate    -0.109356            -0.283998 -0.009977 -0.182312
# Fine_Aggregate      -0.222720            -0.281593  0.079076 -0.450635
# Concrete_Strength    0.497833             0.134824 -0.105753 -0.289613
#
#                      Superplasticizer  Coarse_Aggregate  Fine_Aggregate  \
# Cement                       0.092771         -0.109356       -0.222720
# Blast_Furnance_Slag          0.043376         -0.283998       -0.281593
# Fly_Ash                      0.377340         -0.009977        0.079076
# ...

# %%
df.select_dtypes(include=["float64"]).cov()
# Out:
#                            Cement  Blast_Furnance_Slag      Fly_Ash  \
# Cement               10921.742654         -2481.359426 -2658.350754
# Blast_Furnance_Slag  -2481.359426          7444.083725 -1786.607591
# Fly_Ash              -2658.350754         -1786.607591  4095.548093
# Water                 -181.989792           197.678554  -351.297119
# Superplasticizer        57.914616            22.355312   144.250263
# Coarse_Aggregate      -888.608507         -1905.210572   -49.644195
# Fine_Aggregate       -1866.151111         -1947.911259   405.736351
# Concrete_Strength      869.147620           194.329352  -113.061378
#
#                           Water  Superplasticizer  Coarse_Aggregate  \
# Cement              -181.989792         57.914616       -888.608507
# Blast_Furnance_Slag  197.678554         22.355312      -1905.210572
# Fly_Ash             -351.297119        144.250263        -49.644195
# Water                456.060245        -83.870964       -302.724310
# ...

# %% [markdown]
# ## Correlation Graph => Range = -1 to 1

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=df.corr(), annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# ## Central Limit Theorem (CLT)

# %%
sns.kdeplot(data=df, x='Blast_Furnance_Slag', fill=True, color='red')
plt.show()
