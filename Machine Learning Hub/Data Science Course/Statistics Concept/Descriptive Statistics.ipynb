# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"D:\Ultimate Programming\Data Bases\ESD.xlsx")
df.head(4)
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# 1     0.00          China  Chongqing        NaT
# 2     0.20  United States    Chicago        NaT
# 3     0.07  United States    Chicago        NaT

# %%
df.drop(columns=["EEID", "Exit Date", "Bonus %"], inplace=True, axis=1)

# %%
df.head(4)
# Out:
#          Full Name                 Job Title Department  \
# 0      Emily Davis                Sr. Manger         IT
# 1    Theodore Dinh       Technical Architect         IT
# 2     Luna Sanders                  Director    Finance
# 3  Penelope Jordan  Computer Systems Manager         IT
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
#
#          Country       City
# 0  United States    Seattle
# 1          China  Chongqing
# 2  United States    Chicago
# 3  United States    Chicago

# %%
mn = df["Annual Salary"].mean()

# %%
md = df["Annual Salary"].median()

# %%
me = df["Annual Salary"].mode()[0]

# %%
print(mn, md, me)
# Out:
# 113217.365 96557.0 70165

# %%
plt.figure(figsize=(10,7))
sns.histplot(x="Annual Salary", data=df)
plt.plot([mn for i in range(0, 200)], [i for i in range(0, 200)], c="green", label="mean")
plt.plot([md for i in range(0, 200)], [i for i in range(0, 200)], c="red", label="median")
plt.plot([me for i in range(0, 200)], [i for i in range(0, 200)], c="yellow", label="mode")

plt.legend()
plt.show()

# %%
df.describe()
# Out:
#                Age                   Hire Date  Annual Salary
# count  1000.000000                        1000    1000.000000
# mean     44.382000  2012-04-07 02:54:14.400000  113217.365000
# min      25.000000         1992-01-09 00:00:00   40063.000000
# 25%      35.000000         2007-02-14 00:00:00   71430.250000
# 50%      45.000000         2014-02-15 12:00:00   96557.000000
# 75%      54.000000         2018-06-22 00:00:00  150782.250000
# max      65.000000         2021-12-26 00:00:00  258498.000000
# std      11.246981                         NaN   53545.985644
