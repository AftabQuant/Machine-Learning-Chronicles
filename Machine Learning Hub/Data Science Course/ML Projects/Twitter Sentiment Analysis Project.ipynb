# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
col = ['twitter_id', 'entity', 'sentiment', 'tweet_content']
train_data = pd.read_csv(r"D:\Ultimate Programming\Data Bases\Project Dataset\Twitter\twitter_training.csv")
val_data = pd.read_csv(r"D:\Ultimate Programming\Data Bases\Project Dataset\Twitter\twitter_validation.csv")

train_data.columns = col
val_data.columns = col

# %%
train_data.head(2)
# Out:
#    twitter_id       entity sentiment  \
# 0        2401  Borderlands  Positive
# 1        2401  Borderlands  Positive
#
#                                        tweet_content
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...

# %%
val_data.head(2)
# Out:
#    twitter_id     entity sentiment  \
# 0         352     Amazon   Neutral
# 1        8312  Microsoft  Negative
#
#                                        tweet_content
# 0  BBC News - Amazon boss Jeff Bezos rejects clai...
# 1  @Microsoft Why do I pay for WORD when it funct...

# %% [markdown]
# ## Data Cleaning Part

# %%
(train_data.isnull().sum().sum() / (train_data.shape[0] * train_data.shape[1])) * 100
# Out:
# np.float64(0.2296434166655508)

# %%
train_data.dropna(inplace=True)

# %%
(train_data.isnull().sum().sum() / (train_data.shape[0] * train_data.shape[1])) * 100
# Out:
# np.float64(0.0)

# %%
(val_data.isnull().sum().sum() / (val_data.shape[0] * val_data.shape[1])) * 100
# Out:
# np.float64(0.0)
