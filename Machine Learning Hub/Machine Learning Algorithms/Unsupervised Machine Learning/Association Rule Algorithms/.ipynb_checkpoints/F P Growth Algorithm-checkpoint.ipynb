# %%
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Grocery Products Purchase.csv")
df.head(4)
# Out:
#         Product 1            Product 2     Product 3     Product 4 Product 5  \
# 0    citrus fruit  semi-finished bread     margarine   ready soups       NaN
# 1  tropical fruit               yogurt        coffee           NaN       NaN
# 2      whole milk                  NaN           NaN           NaN       NaN
# 3       pip fruit               yogurt  cream cheese  meat spreads       NaN
#
#   Product 6 Product 7 Product 8 Product 9 Product 10  ... Product 23  \
# 0       NaN       NaN       NaN       NaN        NaN  ...        NaN
# 1       NaN       NaN       NaN       NaN        NaN  ...        NaN
# 2       NaN       NaN       NaN       NaN        NaN  ...        NaN
# 3       NaN       NaN       NaN       NaN        NaN  ...        NaN
#
#   Product 24 Product 25 Product 26 Product 27 Product 28 Product 29  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
market = []

for i in range(df.shape[0]) :
    cus = []
    for j in df.columns :
        if type(df[j][i]) is str:
            cus.append(df[j][i])
    market.append(cus)

# %%
# Convert a single list

nums = []

for i in market :
    for j in i :
        nums.append(j)

# %%
import collections

data = collections.Counter(nums)

# %%
dataset = pd.DataFrame({'items': data.keys(), 'values': data.values()})
dataset.head(4)
# Out:
#                  items  values
# 0         citrus fruit     814
# 1  semi-finished bread     174
# 2            margarine     576
# 3          ready soups      18

# %%
dataset = dataset.sort_values(by="values", ascending=False)

# %%
dataset.head(4)
# Out:
#                items  values
# 7         whole milk    2513
# 11  other vegetables    1903
# 17        rolls/buns    1809
# 31              soda    1715

# %%
from mlxtend.preprocessing import TransactionEncoder

tr = TransactionEncoder()
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
new_df = pd.DataFrame(tr.transform(market), columns=tr.columns_)
new_df.head(2)
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
#
#    baby cosmetics  baby food   bags  baking powder  bathroom cleaner   beef  \
# 0           False      False  False          False             False  False
# 1           False      False  False          False             False  False
#
#    ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0  ...   False    False    False               False   False        False
# 1  ...   False    False    False               False   False        False
#
#    white wine  whole milk  yogurt  zwieback
# 0       False       False   False     False
# 1       False       False    True     False
#
# [2 rows x 169 columns]

# %% [markdown]
# # Apriori Algorithm

# %%
from mlxtend.frequent_patterns import apriori

# %%
apriori(new_df,min_support=0.05,max_len=3, use_colnames=True).sort_values(by='support')
# Out:
#      support                        itemsets
# 13  0.052364                       (napkins)
# 0   0.052466                          (beef)
# 8   0.053279                          (curd)
# 4   0.055414                        (butter)
# 30  0.056024            (whole milk, yogurt)
# 29  0.056634        (rolls/buns, whole milk)
# 18  0.057651                          (pork)
# 7   0.058058                        (coffee)
# 12  0.058566                     (margarine)
# 10  0.058973                   (frankfurter)
# 9   0.063447                 (domestic eggs)
# 3   0.064870                   (brown bread)
# 25  0.071683            (whipped/sour cream)
# 11  0.072293         (fruit/vegetable juice)
# 28  0.074835  (other vegetables, whole milk)
# 17  0.075648                     (pip fruit)
# 5   0.077682                   (canned beer)
# 14  0.079817                    (newspapers)
# 1   0.080529                  (bottled beer)
# 6   0.082766                  (citrus fruit)
# ...

# %% [markdown]
# # F P Growth Algorithm

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
fpgrowth(new_df, min_support=0.05, use_colnames=True, max_len=3).sort_values(by='support')
# Out:
#      support                        itemsets
# 24  0.052364                       (napkins)
# 13  0.052466                          (beef)
# 12  0.053279                          (curd)
# 8   0.055414                        (butter)
# 28  0.056024            (whole milk, yogurt)
# 30  0.056634        (rolls/buns, whole milk)
# 26  0.057651                          (pork)
# 4   0.058058                        (coffee)
# 1   0.058566                     (margarine)
# 15  0.058973                   (frankfurter)
# 27  0.063447                 (domestic eggs)
# 23  0.064870                   (brown bread)
# 25  0.071683            (whipped/sour cream)
# 17  0.072293         (fruit/vegetable juice)
# 29  0.074835  (other vegetables, whole milk)
# 6   0.075648                     (pip fruit)
# 20  0.077682                   (canned beer)
# 16  0.079817                    (newspapers)
# 10  0.080529                  (bottled beer)
# 0   0.082766                  (citrus fruit)
# ...
