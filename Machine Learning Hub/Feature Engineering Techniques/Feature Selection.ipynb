# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\Ultimate Programming\Data Bases\Cleaned Dataset\Smoking Data.csv")
df.head()
# Out:
#    Year Age_Group  Gender  Smoking_Prevalence  Drug_Experimentation  \
# 0  2024     15-19    Both               18.85                 32.40
# 1  2024     10-14  Female               34.88                 41.57
# 2  2023     10-14    Both               42.00                 56.80
# 3  2024     40-49    Both               33.75                 42.90
# 4  2023     15-19    Male               47.90                 39.62
#
#   Socioeconomic_Status  Peer_Influence School_Programs  Family_Background  \
# 0                 High               5             Yes                  1
# 1                 High               6             Yes                 10
# 2                 High               6             Yes                  2
# 3               Middle              10              No                  9
# 4                 High               1              No                  2
#
#    Mental_Health Access_to_Counseling  Parental_Supervision  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

oe = OneHotEncoder()
for col in df.select_dtypes(include='object').columns:
    df[col] = oe.fit_transform(df[[col]]).toarray()

# %%
df.head(3)
# Out:
#    Year  Age_Group  Gender  Smoking_Prevalence  Drug_Experimentation  \
# 0  2024        0.0     1.0               18.85                 32.40
# 1  2024        1.0     0.0               34.88                 41.57
# 2  2023        1.0     1.0               42.00                 56.80
#
#    Socioeconomic_Status  Peer_Influence  School_Programs  Family_Background  \
# 0                   1.0               5              0.0                  1
# 1                   1.0               6              0.0                 10
# 2                   1.0               6              0.0                  2
#
#    Mental_Health  Access_to_Counseling  Parental_Supervision  \
# 0              5                   1.0                     4
# 1              5                   1.0                     9
# 2              7                   0.0                     2
#
#    Substance_Education  Community_Support  Media_Influence
# 0                  1.0                  3                1
# ...

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %%
df.describe()
# Out:
#                Year     Age_Group        Gender  Smoking_Prevalence  \
# count  10000.000000  10000.000000  10000.000000        10000.000000
# mean    2022.000500      0.501100      0.100700           27.439257
# std        1.425027      0.500024      0.300946           12.975528
# min     2020.000000      0.000000      0.000000            5.000000
# 25%     2021.000000      0.000000      0.000000           16.160000
# 50%     2022.000000      1.000000      0.000000           27.355000
# 75%     2023.000000      1.000000      0.000000           38.672500
# max     2024.000000      1.000000      1.000000           50.000000
#
#        Drug_Experimentation  Socioeconomic_Status  Peer_Influence  \
# count          10000.000000          10000.000000    10000.000000
# mean              40.150182              0.341500        5.440100
# std               17.515917              0.474236        2.863151
# min               10.000000              0.000000        1.000000
# ...

# %% [markdown]
# # Feature Selection Technique:

# %%
from mlxtend.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LogisticRegression

x = df.iloc[:,:-1]
y = df['Media_Influence']

# %%
x.shape
# Out:
# (10000, 14)

# %%
y.shape
# Out:
# (10000,)

# %%
lr = LogisticRegression()
fs = SequentialFeatureSelector(lr, k_features=14, forward=True)
fs.fit(x, y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(), k_features=(14, 14),
#                           scoring='accuracy')

# %%
fs.feature_names
# Out:
# ['Year',
#  'Age_Group',
#  'Gender',
#  'Smoking_Prevalence',
#  'Drug_Experimentation',
#  'Socioeconomic_Status',
#  'Peer_Influence',
#  'School_Programs',
#  'Family_Background',
#  'Mental_Health',
#  'Access_to_Counseling',
#  'Parental_Supervision',
#  'Substance_Education',
#  'Community_Support']

# %%
fs.k_feature_names_
# Out:
# ('Year',
#  'Age_Group',
#  'Gender',
#  'Smoking_Prevalence',
#  'Drug_Experimentation',
#  'Socioeconomic_Status',
#  'Peer_Influence',
#  'School_Programs',
#  'Family_Background',
#  'Mental_Health',
#  'Access_to_Counseling',
#  'Parental_Supervision',
#  'Substance_Education',
#  'Community_Support')

# %%
print(fs.k_score_)
# Out:
# 0.10540000000000001

# %%
best_score = 0
best_k = 0
for k in range(1, 5):
    fs.fit(x, y)
    score = fs.k_score_
    if score > best_score:
        best_score = score
        best_k = k

print(best_score, best_k)
# Out:
# 0.10540000000000001 1

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.20)

# %%
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (8000, 14) (2000, 14)
# (8000,) (2000,)
