# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\Ultimate Programming\Data Bases\Machine Learning Datasets\Classification\churn_data.csv")

# %%
df.head(3)
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
#
#       PaymentMethod  MonthlyCharges TotalCharges Churn
# 0  Electronic check           29.85        29.85    No
# 1      Mailed check           56.95       1889.5    No
# 2      Mailed check           53.85       108.15   Yes

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in df.select_dtypes(include='object').columns:
    df[col] = le.fit_transform(df[col])

# %%
df.head(2)
# Out:
#    customerID  tenure  PhoneService  Contract  PaperlessBilling  \
# 0        5375       1             0         0                 1
# 1        3962      34             1         1                 0
#
#    PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 0              2           29.85          2505      0
# 1              3           56.95          1466      0

# %%
df = df.drop('customerID', axis=1)

# %%
df.describe()
# Out:
#             tenure  PhoneService     Contract  PaperlessBilling  \
# count  7043.000000   7043.000000  7043.000000       7043.000000
# mean     32.371149      0.903166     0.690473          0.592219
# std      24.559481      0.295752     0.833755          0.491457
# min       0.000000      0.000000     0.000000          0.000000
# 25%       9.000000      1.000000     0.000000          0.000000
# 50%      29.000000      1.000000     0.000000          1.000000
# 75%      55.000000      1.000000     1.000000          1.000000
# max      72.000000      1.000000     2.000000          1.000000
#
#        PaymentMethod  MonthlyCharges  TotalCharges        Churn
# count    7043.000000     7043.000000   7043.000000  7043.000000
# mean        1.574329       64.761692   3257.794122     0.265370
# std         1.068104       30.090047   1888.693496     0.441561
# min         0.000000       18.250000      0.000000     0.000000
# 25%         1.000000       35.500000   1609.000000     0.000000
# 50%         2.000000       70.350000   3249.000000     0.000000
# 75%         2.000000       89.850000   4901.500000     1.000000
# max         3.000000      118.750000   6530.000000     1.000000

# %%
df.duplicated().sum().sum()
# Out:
# np.int64(79)

# %%
df.drop_duplicates(inplace=True)

# %%
x = df.iloc[:, :-1]
y = df['Churn']

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
for col in x:
    x[col] = ss.fit_transform(x[[col]])

# %% [markdown]
# ## Under Sampling

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
y.value_counts()
# Out:
# Churn
# 0    5141
# 1    1823
# Name: count, dtype: int64

# %%
ru = RandomUnderSampler()
ru_x, ru_y = ru.fit_resample(x, y)

# %%
ru_y.value_counts()
# Out:
# Churn
# 0    1823
# 1    1823
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(ru_x, ru_y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 75.06849315068493

# %% [markdown]
# ## Over Sampling

# %%
y.value_counts()
# Out:
# Churn
# 0    5141
# 1    1823
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler
ro = RandomOverSampler()
ro_x, ro_y = ro.fit_resample(x, y)

# %%
ro_y.value_counts()
# Out:
# Churn
# 0    5141
# 1    5141
# Name: count, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(ro_x, ro_y, test_size=0.2, random_state=42)

# %%
lr2 = LogisticRegression()
lr2.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr2.score(x_test, y_test)*100
# Out:
# 76.32474477394263

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# %%
cm = confusion_matrix(y_test, lr2.predict(x_test))

# %%
sns.heatmap(cm, annot=True)
plt.show()

# %%
print(precision_score(y_test, lr.predict(x_test))*100)
print(recall_score(y_test, lr.predict(x_test))*100)
print(f1_score(y_test, lr.predict(x_test))*100)
# Out:
# 72.82511210762331
# 81.2
# 76.78486997635933

# %% [markdown]
# ## Naive Bayes Algorithm

# %%
ros = RandomOverSampler()
ros_x, ros_y = ros.fit_resample(x, y)

# %%
x_train, x_test, y_train, y_test = train_test_split(ros_x, ros_y, test_size=0.2, random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB

# %%
gnb = GaussianNB()
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_test, y_test)*100
# Out:
# 74.91492464754496

# %%
bnb = BernoulliNB()
bnb.fit(x_train, y_train)
# Out:
# BernoulliNB()

# %%
bnb.score(x_test, y_test)*100
# Out:
# 74.1370928536704
